# %%
pip install tmdbsimple

# %%
# !python -m pip install requests

# %%
#Api Read Acces Token
#eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjZWRmZGE4NTliNjUwYjI5ZjU2YWYyZDZhZTg2NThkNiIsInN1YiI6IjY0MWRlZWNiYzk5ODI2MDBiYTQ3NTg3NCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.nhRFhmi621MstknliXTrfntO7a-n8tv7KAe5mytJ_Qw

#Api Key
#cedfda859b650b29f56af2d6ae8658d6

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = 'cedfda859b650b29f56af2d6ae8658d6'

# %%
import requests
tmdb.REQUESTS_SESSION = requests.Session()

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = 'cedfda859b650b29f56af2d6ae8658d6'

movie = tmdb.Movies(268) # Batman Collection (1999)
response = movie.info()

# Imprime información detallada sobre la película
print(response)
# Out:
# {'adult': False, 'backdrop_path': '/frDS8A5vIP927KYAxTVVKRIbqZw.jpg', 'belongs_to_collection': {'id': 120794, 'name': 'Batman Collection', 'poster_path': '/4AUoqt72CVP4UV902hmdDj4t5Q9.jpg', 'backdrop_path': '/4UHZWw5lV3ZoadTjXuVOakdH32L.jpg'}, 'budget': 35000000, 'genres': [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}], 'homepage': '', 'id': 268, 'imdb_id': 'tt0096895', 'original_language': 'en', 'original_title': 'Batman', 'overview': 'Batman must face his most ruthless nemesis when a deformed madman calling himself "The Joker" seizes control of Gotham\'s criminal underworld.', 'popularity': 50.014, 'poster_path': '/cij4dd21v2Rk2YtUQbV5kW69WB2.jpg', 'production_companies': [{'id': 4357, 'logo_path': None, 'name': 'The Guber-Peters Company', 'origin_country': ''}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 1382, 'logo_path': '/sOg7LGESPH5vCTOIdbMhLuypoLL.png',
# ...

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = 'cedfda859b650b29f56af2d6ae8658d6'

search = tmdb.Search()
response = search.movie(query='movies')

for result in response['results']:
    movie = tmdb.Movies(result['id'])
    movie_info = movie.info()
    print(result['title'], movie_info['runtime'])
# Out:
# Movies 0
# Movies 0
# Sword Art Online the Movie -Progressive- Scherzo of Deep Night 100
# Movies 0
# Miraculous: Ladybug & Cat Noir, The Movie 107
# Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train 117
# That Time I Got Reincarnated as a Slime the Movie: Scarlet Bond 108
# The Quintessential Quintuplets Movie 136
# The Ten Commandments: The Movie 120
# Naruto Shippuden the Movie 94
# The Last: Naruto the Movie 114
# X-Rated: The Greatest Adult Movies of All Time 94
# Pokémon the Movie: Secrets of the Jungle 101
# Boruto: Naruto the Movie 95
# A Silent Voice: The Movie 130
# Naruto Shippuden the Movie: Blood Prison 108
# Easy Sex, Sad Movies 90
# Sailor Moon SuperS: The Movie: Black Dream Hole 60
# Road to Ninja: Naruto the Movie 109
# Kuroko's Basketball the Movie: Last Game 90

# %%
import tmdbsimple as tmdb
import pandas as pd

tmdb.API_KEY = 'cedfda859b650b29f56af2d6ae8658d6'

search = tmdb.Search()
response = search.movie(query='movies')

movies = []
for result in response['results']:
    movie = {
        'title': result['title'],
        'release_date': result['release_date'],
        'popularity': result['popularity']
    }
    movies.append(movie)

df = pd.DataFrame(movies)
print(df)
# Out:
#                                                 title release_date  popularity
# 0                                              Movies                    1.546
# 1                                              Movies                    0.600
# 2   Sword Art Online the Movie -Progressive- Scher...   2022-10-22     247.353
# 3                                              Movies                    0.600
# 4           Miraculous: Ladybug & Cat Noir, The Movie   2023-07-05     304.840
# 5   Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...   2020-10-16     132.360
# 6   That Time I Got Reincarnated as a Slime the Mo...   2022-11-25     138.136
# 7                The Quintessential Quintuplets Movie   2022-05-20      91.576
# 8                     The Ten Commandments: The Movie   2016-01-28      26.888
# 9                          Naruto Shippuden the Movie   2007-08-04      79.180
# 10                         The Last: Naruto the Movie   2014-12-06      51.872
# ...

# %%
import tmdbsimple as tmdb
import pandas as pd

tmdb.API_KEY = 'cedfda859b650b29f56af2d6ae8658d6'

search = tmdb.Search()
movies = []
for page in range(1, 10):
    response = search.movie(query='movies', page=page)
    for result in response['results']:
        movie_id = result['id']
        movie_details = tmdb.Movies(movie_id).info()
        movie = {
            'title': result['title'],
            'release_date': result['release_date'],
            'popularity': result['popularity'],
            'genres': [genre['name'] for genre in movie_details['genres']],
            'budget': movie_details['budget'],
            'revenue': movie_details['revenue'],
            'vote_average': movie_details['vote_average'],
            'runtime': movie_details['runtime']
        }
        movies.append(movie)

df = pd.DataFrame(movies)
print(df)
# Out:
#                                                  title release_date  \
# 0                                               Movies
# 1                                               Movies
# 2    Sword Art Online the Movie -Progressive- Scher...   2022-10-22
# 3                                               Movies
# 4            Miraculous: Ladybug & Cat Noir, The Movie   2023-07-05
# ..                                                 ...          ...
# 175                        The New Employee: The Movie   2023-04-30
# 176  THE iDOLM@STER MOVIE: Beyond the Brilliant Fut...   2014-01-25
# 177                         Yowamushi Pedal: The Movie   2015-08-28
# 178                       Break the Silence: The Movie   2020-09-10
# 179                         Animal Crossing: The Movie   2006-12-16
#
#      popularity                                         genres    budget  \
# 0         1.546                                             []         0
# ...

# %%
print(df.to_string())
# Out:
#                                                                                                   title release_date  popularity                                                                    genres     budget    revenue  vote_average  runtime
# 0                                                                                                Movies                    1.546                                                                        []          0          0         4.200        0
# 1                                                                                                Movies                    0.600                                                                        []          0          0         1.700        0
# 2                                        Sword Art Online the Movie -Progressive- Scherzo of Deep Night   2022-10-22     247.353                             [Animation, Action, Fantasy, Science Fiction]          0          0         7.600      100
# ...

# %%
print(df.iloc[0:100].to_string())
# Out:
#                                                                                                  title release_date  popularity                                                             genres     budget    revenue  vote_average  runtime
# 0                                                                                               Movies                    1.546                                                                 []          0          0         4.200        0
# 1                                                                                               Movies                    0.600                                                                 []          0          0         1.700        0
# 2                                       Sword Art Online the Movie -Progressive- Scherzo of Deep Night   2022-10-22     247.353                      [Animation, Action, Fantasy, Science Fiction]          0          0         7.600      100
# ...

# %%
print(df.shape)
# Out:
# (180, 8)

# %%
import numpy as np

# %%
df.head(5)
# Out:
#                                                title release_date  popularity  \
# 0                                             Movies                    1.546
# 1                                             Movies                    0.600
# 2  Sword Art Online the Movie -Progressive- Scher...   2022-10-22     247.353
# 3                                             Movies                    0.600
# 4          Miraculous: Ladybug & Cat Noir, The Movie   2023-07-05     304.840
#
#                                           genres    budget  revenue  \
# 0                                             []         0        0
# 1                                             []         0        0
# 2  [Animation, Action, Fantasy, Science Fiction]         0        0
# 3                                             []         0        0
# 4  [Animation, Family, Action, Fantasy, Romance]  86000000        0
#
#    vote_average  runtime
# 0           4.2        0
# 1           1.7        0
# ...

# %%
df['release_date'] = df['release_date'].fillna(np.nan)

# %%
df['release_date'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# Name: release_date, Length: 180, dtype: bool

# %%
df['release_date'] = df['release_date'].replace('',np.nan)
df['release_date'].head()
# Out:
# 0           NaN
# 1           NaN
# 2    2022-10-22
# 3           NaN
# 4    2023-07-05
# Name: release_date, dtype: object

# %%
df = df.replace(0, np.nan)

df.head(20)
# Out:
#                                                 title release_date  \
# 0                                              Movies          NaN
# 1                                              Movies          NaN
# 2   Sword Art Online the Movie -Progressive- Scher...   2022-10-22
# 3                                              Movies          NaN
# 4           Miraculous: Ladybug & Cat Noir, The Movie   2023-07-05
# 5   Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...   2020-10-16
# 6   That Time I Got Reincarnated as a Slime the Mo...   2022-11-25
# 7                The Quintessential Quintuplets Movie   2022-05-20
# 8                     The Ten Commandments: The Movie   2016-01-28
# 9                          Naruto Shippuden the Movie   2007-08-04
# 10                         The Last: Naruto the Movie   2014-12-06
# 11     X-Rated: The Greatest Adult Movies of All Time   2015-02-06
# 12           Pokémon the Movie: Secrets of the Jungle   2020-12-25
# ...

# %%
df['genres'] = df['genres'].replace('[]',np.nan)
df['genres'].head()
# Out:
# 0                                               []
# 1                                               []
# 2    [Animation, Action, Fantasy, Science Fiction]
# 3                                               []
# 4    [Animation, Family, Action, Fantasy, Romance]
# Name: genres, dtype: object

# %%
df['genres'].dtypes
# Out:
# dtype('O')

# %%
print(df.genres)
# Out:
# 0                                                NaN
# 1                                                NaN
# 2      [Animation, Action, Fantasy, Science Fiction]
# 3                                                NaN
# 4      [Animation, Family, Action, Fantasy, Romance]
#                            ...
# 175                                        [Romance]
# 176                        [Animation, Drama, Music]
# 177                              [Action, Animation]
# 178                             [Music, Documentary]
# 179                       [Animation, Drama, Family]
# Name: genres, Length: 180, dtype: object

# %%
import numpy as np
mask = df['genres'].apply(lambda x: len(x) == 0)
df.loc[mask, 'genres'] = np.nan

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# title             0
# release_date      3
# popularity        0
# genres            4
# budget          161
# revenue         135
# vote_average      9
# runtime          12
# dtype: int64

# %%
df.isnull()
# Out:
#      title  release_date  popularity  genres  budget  revenue  vote_average  \
# 0    False          True       False    True    True     True         False
# 1    False          True       False    True    True     True         False
# 2    False         False       False   False    True     True         False
# 3    False          True       False    True    True     True          True
# 4    False         False       False   False   False     True         False
# ..     ...           ...         ...     ...     ...      ...           ...
# 175  False         False       False   False    True     True          True
# 176  False         False       False   False    True     True         False
# 177  False         False       False   False    True     True         False
# 178  False         False       False   False    True    False         False
# 179  False         False       False   False    True     True         False
#
#      runtime
# 0       True
# 1       True
# ...

# %%
df.isnull().sum()
# Out:
# title             0
# release_date      3
# popularity        0
# genres            4
# budget          161
# revenue         135
# vote_average      9
# runtime          12
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0      5
# 1      5
# 2      2
# 3      6
# 4      1
#       ..
# 175    3
# 176    2
# 177    2
# 178    1
# 179    2
# Length: 180, dtype: int64
